# %%
import pandas as pd
dataf = pd.read_csv(r'D:\real_estate.csv')
dataf.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
dataf.shape
# Out:
# (414, 8)

# %%
dataf.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
dataf.rename(columns={'X2 house age':'Age','Y house price of unit area':'Rate'},inplace=True)

# %%
dataf.head()
# Out:
#    No  X1 transaction date   Age  X3 distance to the nearest MRT station  \
# 0   1             2012.917  32.0                                84.87882
# 1   2             2012.917  19.5                               306.59470
# 2   3             2013.583  13.3                               561.98450
# 3   4             2013.500  13.3                               561.98450
# 4   5             2012.833   5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  Rate
# 0                               10     24.98298     121.54024  37.9
# 1                                9     24.98034     121.53951  42.2
# 2                                5     24.98746     121.54391  47.3
# 3                                5     24.98746     121.54391  54.8
# 4                                5     24.97937     121.54245  43.1

# %%
X = 'Age'
Y = 'Rate'
data,target=dataf[[X]],dataf[Y]

# %%
from sklearn.linear_model import LinearRegression
linear_regression = LinearRegression()
linear_regression.fit(data, target)
w,b = linear_regression.coef_[0],linear_regression.intercept_
print(w,b)
# Out:
# -0.25148841908534547 42.4346970462629

# %%
import numpy as np
age = np.linspace(data.min(), data.max())
pred_rate = w*age + b
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(x=data[X], y=target, color="black", alpha=0.5)
plt.plot(age, pred_rate)
plt.title("Model using LinearRegression from scikit-learn")
# Out:
# Text(0.5, 1.0, 'Model using LinearRegression from scikit-learn')

# %%
#Logistic Regression
dataf = pd.read_csv(r'D:\heart.csv')
dataf=dataf[dataf.diaBP>=90]
dataf.head()
# Out:
#     male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 3      0   61        3.0              1        30.0     0.0                0
# 5      0   43        2.0              0         0.0     0.0                0
# 9      1   43        1.0              1        30.0     0.0                0
# 12     1   46        1.0              1        15.0     0.0                0
# 15     0   38        2.0              1        20.0     0.0                0
#
#     prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 3              1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 5              1         0    228.0  180.0  110.0  30.30       77.0     99.0
# 9              1         0    225.0  162.0  107.0  23.61       93.0     88.0
# 12             1         0    294.0  142.0   94.0  26.31       98.0     64.0
# 15             1         0    221.0  140.0   90.0  21.35       95.0     70.0
#
#     TenYearCHD
# 3            1
# ...

# %%
X='diaBP'
Y='TenYearCHD'
data,target=dataf[[X]],dataf[Y]

# %%
from sklearn.linear_model import LogisticRegression
lo_regression = LogisticRegression()
lo_regression.fit(data, target)
# Out:
# LogisticRegression()

# %%
X_test = np.linspace(data.min(), data.max(), 300).reshape(-1, 1)
Y_prob = lo_regression.predict_proba(X_test)[:, 1]
plt.scatter(data, target, color='blue', label='Data points')
plt.plot(X_test, Y_prob, color='red', label='Logistic Regression Curve')
plt.xlabel(X)
plt.ylabel(Y)
plt.title('Logistic Regression Fit')
plt.legend()
plt.show()
# Out:
# C:\Users\veera\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
#Easy method using seaborn
import seaborn as sns
sns.regplot(x=data,y=target,logistic=True,ci=None)
# Out:
# <Axes: xlabel='diaBP', ylabel='TenYearCHD'>
