# %%
#Broadcasting

import numpy as np
A=np.array([[56,0,4.4,68],
           [1.2,104.0,52.0,8.0],
           [1.8,135,99,0.9]])

# %%
calc=A.sum(axis=0)
print(calc)
# Out:
# [ 59.  239.  155.4  76.9]

# %%
percentage=100*A/calc.reshape(1,4)
print(percentage)#Percentage coloumn wise
# Out:
# [[94.91525424  0.          2.83140283 88.42652796]
#  [ 2.03389831 43.51464435 33.46203346 10.40312094]
#  [ 3.05084746 56.48535565 63.70656371  1.17035111]]

# %%
A=np.array([[1,2,3],
            [4,5,6]])#(m,n)=(2,3)
B=np.array([[100,200,300]])#(1,n)=(1,3)
print(A+B)#Python makes the 1,n to m,n by repeating and finally adds..either m or n shud be common
# Out:
# [[101 202 303]
#  [104 205 306]]

# %%
# !pip install tensorflow

# %%
#Regression with keras
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn

# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

# Keras specific
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
df = pd.read_csv(r'D:\economics.csv',usecols=['pce','pop','psavert','uempmed','unemploy']) 
print(df.shape)
df.describe()
# Out:
# (574, 5)
#                 pce            pop     psavert     uempmed      unemploy
# count    574.000000     574.000000  574.000000  574.000000    574.000000
# mean    4820.092683  257159.652662    8.567247    8.608711   7771.310105
# std     3556.803613   36682.398508    2.964179    4.106645   2641.959180
# min      506.700000  198712.000000    2.200000    4.000000   2685.000000
# 25%     1578.300000  224896.000000    6.400000    6.000000   6284.000000
# 50%     3936.850000  253060.000000    8.400000    7.500000   7494.000000
# 75%     7626.325000  290290.750000   11.100000    9.100000   8685.500000
# max    12193.800000  320402.295000   17.300000   25.200000  15352.000000

# %%
target_column = ['unemploy'] 
predictors = list(set(list(df.columns))-set(target_column))
df[predictors] = df[predictors]/df[predictors].max()
df.describe()
# Out:
#               pce         pop     psavert     uempmed      unemploy
# count  574.000000  574.000000  574.000000  574.000000    574.000000
# mean     0.395290    0.802615    0.495217    0.341616   7771.310105
# std      0.291690    0.114489    0.171340    0.162962   2641.959180
# min      0.041554    0.620195    0.127168    0.158730   2685.000000
# 25%      0.129435    0.701918    0.369942    0.238095   6284.000000
# 50%      0.322857    0.789820    0.485549    0.297619   7494.000000
# 75%      0.625426    0.906020    0.641618    0.361111   8685.500000
# max      1.000000    1.000000    1.000000    1.000000  15352.000000

# %%
X = df[predictors].values
y = df[target_column].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=40)

# %%
model = Sequential()#we would be using the Sequential model because our network consists of a linear stack of layers.
model.add(Dense(500, input_dim=4, activation= "relu"))#The second line of code represents the first layer which specifies the activation function and the number of input dimensions, which in our case is 4 predictors. 
model.add(Dense(100, activation= "relu"))
model.add(Dense(50, activation= "relu"))#Then we repeat the same process in the third and fourth line of codes for the hidden layers, this time without the input_dim parameter.
model.add(Dense(1))#The last line of code creates the output layer with one node that is supposed to output the number of unemployed in thousands.
# Out:
# C:\Users\veera\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#The activation function used in the hidden layers is a rectified linear unit, or ReLU. It is the most widely used activation function because of its advantages of being nonlinear, as well as the ability to not activate all the neurons at the same time. 
#In simple terms, this means that at a time, only a few neurons are activated, making the network sparse and very efficient.

# %%
model.compile(loss= "mean_squared_error" , optimizer="adam", metrics=["mean_squared_error"])#The mean squared error is our loss measure 
model.fit(X_train, y_train, epochs=20)#The main advantage of the "adam" optimizer is that we don't need to specify the learning rate
#Epoch is the number of training iterations
# Out:
# Epoch 1/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 67104384.0000 - mean_squared_error: 67104384.0000
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 66182000.0000 - mean_squared_error: 66182000.0000
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 65181724.0000 - mean_squared_error: 65181724.0000
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 70642784.0000 - mean_squared_error: 70642784.0000
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 66976364.0000 - mean_squared_error: 66976364.0000
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 64993740.0000 - mean_squared_error: 64993740.0000
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 63544488.0000 - mean_squared_error: 63544488.0000
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 59743972.0000 - mean_squared_error: 59743972.0000
# Epoch 9/20
# ...

# %%
pred_train= model.predict(X_train)
print(np.sqrt(mean_squared_error(y_train,pred_train)))

pred= model.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1867.0105925175037
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1824.7968215141693

# %%
#Classification with keras
# Import required libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn

# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

# Keras specific
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical

# %%
df = pd.read_csv('D:\\diabetes.csv') 
print(df.shape)
df.head()
# Out:
# (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.rename(columns={'BloodPressure':'Diastolic','SkinThickness':'Triceps','DiabetesPedigreeFunction':'DPF','Outcome':'diabetes'},inplace=True)

# %%
target_column = ['diabetes'] 
predictors = list(set(list(df.columns))-set(target_column))
df[predictors] = df[predictors]/df[predictors].max()
df.describe()
# Out:
#        Pregnancies     Glucose   Diastolic     Triceps     Insulin  \
# count   768.000000  768.000000  768.000000  768.000000  768.000000
# mean      0.226180    0.607510    0.566438    0.207439    0.094326
# std       0.198210    0.160666    0.158654    0.161134    0.136222
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%       0.058824    0.497487    0.508197    0.000000    0.000000
# 50%       0.176471    0.587940    0.590164    0.232323    0.036052
# 75%       0.352941    0.704774    0.655738    0.323232    0.150414
# max       1.000000    1.000000    1.000000    1.000000    1.000000
#
#               BMI         DPF         Age    diabetes
# count  768.000000  768.000000  768.000000  768.000000
# mean     0.476790    0.194990    0.410381    0.348958
# std      0.117499    0.136913    0.145188    0.476951
# min      0.000000    0.032231    0.259259    0.000000
# 25%      0.406855    0.100723    0.296296    0.000000
# ...

# %%
X = df[predictors].values
y = df[target_column].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=40)
print(X_train.shape); print(X_test.shape)
# Out:
# (537, 8)
# (231, 8)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

count_classes = y_test.shape[1]
print(count_classes)
# Out:
# 2

# %%
model = Sequential()
model.add(Dense(500, activation='relu', input_dim=8))#8 predictors to predict outcomes
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(2, activation='softmax'))#The fifth line of code creates the output layer with two nodes because there are two output classes, 0 and 1
#We use 'softmax' as the activation function for the output layer, so that the sum of the predicted values from all the neurons in the output layer adds up to one.
# Compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])#Configuring the learning process
# Out:
# C:\Users\veera\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6237 - loss: 0.6699
# Epoch 2/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7043 - loss: 0.6055
# Epoch 3/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6951 - loss: 0.6053
# Epoch 4/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7362 - loss: 0.5595
# Epoch 5/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7173 - loss: 0.5593
# Epoch 6/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7340 - loss: 0.5390
# Epoch 7/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7945 - loss: 0.4686
# Epoch 8/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8153 - loss: 0.4594
# Epoch 9/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7914 - loss: 0.4879
# Epoch 10/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8169 - loss: 0.4574
# Epoch 11/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7724 - loss: 0.4536
# Epoch 12/20
# ...

# %%
pred_train= model.predict(X_train)
scores = model.evaluate(X_train, y_train, verbose=0)
print('Accuracy on training data: {}% \n Error on training data: {}'.format(scores[1], 1 - scores[1]))   
 
pred_test= model.predict(X_test)
scores2 = model.evaluate(X_test, y_test, verbose=0)
print('Accuracy on test data: {}% \n Error on test data: {}'.format(scores2[1], 1 - scores2[1]))
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Accuracy on training data: 0.8119180798530579%
#  Error on training data: 0.18808192014694214
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy on test data: 0.7532467246055603%
#  Error on test data: 0.2467532753944397
